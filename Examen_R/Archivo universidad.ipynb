# %%
import pandas as pd

# %%
df = pd.read_csv('w_university_r.csv')
df.head()
# Out:
#    World Rank                            Institution        Location  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5                   University of Oxford  United Kingdom
#
#    National Rank Education Rank Employability Rank Faculty Rank Research Rank  \
# 0              1              1                  1            1             1
# 1              2              4                 12            2             7
# 2              3             11                  4            3             2
# 3              1              3                 25            4            10
# 4              2              7                 27            9             4
#
#    Score
# 0  100.0
# 1   96.7
# 2   95.1
# 3   94.1
# 4   93.3

# %%
df.isnull().sum()
# Out:
# World Rank            0
# Institution           0
# Location              0
# National Rank         0
# Education Rank        0
# Employability Rank    0
# Faculty Rank          0
# Research Rank         0
# Score                 0
# dtype: int64

# %%
mejor = df[(df['Location']=='Chile')& (df['National Rank'].max())]
mejor
# Out:
#       World Rank                                   Institution Location  \
# 384          385       Pontifical Catholic University of Chile    Chile
# 430          431                           University of Chile    Chile
# 822          823                      University of Concepción    Chile
# 870          871     Federico Santa María Technical University    Chile
# 1169        1170                       Andrés Bello University    Chile
# 1232        1233                   Austral University of Chile    Chile
# 1376        1377                 University of Santiago, Chile    Chile
# 1420        1421  Pontifical Catholic University of Valparaíso    Chile
# 1448        1449                     University of La Frontera    Chile
# 1623        1624                      University of Valparaíso    Chile
# 1627        1628              Catholic University of the North    Chile
# 1723        1724                     Diego Portales University    Chile
# ...

# %%
mejor_peru = df[(df['Location']=='Peru')& (df['National Rank'].max())]
mejor_peru
# Out:
#       World Rank                             Institution Location  \
# 1505        1506    Cayetano Heredia Peruvian University     Peru
# 1580        1581  Pontifical Catholic University of Peru     Peru
#
#       National Rank Education Rank Employability Rank Faculty Rank  \
# 1505              1              -                  -            -
# 1580              2              -               1339            -
#
#      Research Rank  Score
# 1505          1437   67.7
# 1580          1506   67.3

# %%
mejor_chile = df[(df['Location']=='Chile')]
mejor_chile.head()
# Out:
#       World Rank                                Institution Location  \
# 384          385    Pontifical Catholic University of Chile    Chile
# 430          431                        University of Chile    Chile
# 822          823                   University of Concepción    Chile
# 870          871  Federico Santa María Technical University    Chile
# 1169        1170                    Andrés Bello University    Chile
#
#       National Rank Education Rank Employability Rank Faculty Rank  \
# 384               1            510                207            -
# 430               2              -                648            -
# 822               3              -                  -            -
# 870               4              -               1073            -
# 1169              5              -               1629            -
#
#      Research Rank  Score
# 384            389   75.5
# 430            412   74.9
# 822            786   71.4
# 870            829   71.0
# ...

# %%
uni = df[(df['Location']=='Cyprus')]
uni.shape
# Out:
# (2, 9)

# %%
U_ch = df[(df['Location']=='Chile')]
U_ch.shape
# Out:
# (16, 9)

# %%
mejo = df[(df['Location']=='Chile')]
mejo.tail()
# Out:
#       World Rank                     Institution Location  National Rank  \
# 1723        1724       Diego Portales University    Chile             12
# 1817        1818  Autonomous University of Chile    Chile             13
# 1855        1856             University of Talca    Chile             14
# 1937        1938        Adolfo Ibáñez University    Chile             15
# 1998        1999          University of Tarapacá    Chile             16
#
#      Education Rank Employability Rank Faculty Rank Research Rank  Score
# 1723              -                  -            -          1651   66.8
# 1817              -                  -            -          1748   66.4
# 1855              -                  -            -          1784   66.3
# 1937              -                754            -          1889   66.0
# 1998              -                  -            -          1925   65.7

# %%
mejorch = df[(df['Location']=='Chile')]
Am = mejorch.sort_values('Employability Rank',ascending=False)
Am.head()
# Out:
#       World Rank                              Institution Location  \
# 1376        1377            University of Santiago, Chile    Chile
# 1937        1938                 Adolfo Ibáñez University    Chile
# 430          431                      University of Chile    Chile
# 384          385  Pontifical Catholic University of Chile    Chile
# 1169        1170                  Andrés Bello University    Chile
#
#       National Rank Education Rank Employability Rank Faculty Rank  \
# 1376              7              -                981            -
# 1937             15              -                754            -
# 430               2              -                648            -
# 384               1            510                207            -
# 1169              5              -               1629            -
#
#      Research Rank  Score
# 1376          1321   68.2
# 1937          1889   66.0
# 430            412   74.9
# 384            389   75.5
# ...

# %%
peru = df[(df['Location']=='Peru')]
peru.shape
# Out:
# (2, 9)
